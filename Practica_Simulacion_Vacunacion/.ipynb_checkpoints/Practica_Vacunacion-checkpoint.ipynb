# %% [markdown]
# # EXAMEN DE SIMULACIÓN - PRIMER INTERCICLO
# ### Alejandro Enríquez
# ### Ingeniería en Ciencias de la Computación
# ### 9no Ciclo
#
# Objetivo:

# %%
# Imports
import simpy
import random
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Instanciar Variables
NUM_MEDICOS = 6
NUM_PACIENTES = 150

TIEMPO_CONTROL = 2 # Hasta 5
TIEMPO_VACUNACION = 5 # Hasta 10
INTERVALO_LLEGADA = 15
POST_VACUNA = 1 # Hasta 3
ESPERA_INICIAL = 20

vacunados = 0
no_vacunados = 0
pacientes = 0
pacientes_atendidos = 0
bandera = 1
tiempo = 0

proceso = pd.DataFrame(columns=['pacientes','vacunados','no_vacunados'])

# %%
class Centro_Vacunacion(object):
    def __init__(self, environment, num_medicos, num_pacientes):
        self.env = environment
        self.num_medicos = simpy.Resource(environment, num_medicos)
        self.num_pacientes = simpy.Resource(environment, num_pacientes)
        
    def llega_paciente(self, paciente):
        print("El %s llega a las %.2f. " % (paciente, env.now))
        yield self.env.timeout(ESPERA_INICIAL)
        print("El %s entra a la fila a las %.2f. " % (paciente, env.now))
    
    def vacunar(self, paciente):
        global bandera
        global no_vacunados
        complicaciones = random.randint(1,100)
        print("El %s pasa a revisión en el padrón a las %.2f. " % (paciente, env.now))
        yield self.env.timeout(random.randint(TIEMPO_CONTROL, TIEMPO_CONTROL+3))
        if complicaciones < 95:
            print("El %s empieza la vacunación a las %.2f. " % (paciente, env.now))
            yield self.env.timeout(random.randint(TIEMPO_VACUNACION, TIEMPO_VACUNACION+5))
            print("El %s termina la vacunación a las %.2f. " % (paciente, env.now))
            bandera = 1
        else:
            print("!X!X!X! El %s no puede vacunarse y se retira a las %.2f." % (paciente, env.now))
            no_vacunados = no_vacunados+1
            bandera = 0
    
    def salida(self, paciente):
        global bandera
        global pacientes_atendidos
        if bandera == 1:
            print("El %s es llevado a la salida a las %.2f. " % (paciente, env.now))
            yield self.env.timeout(random.randint(POST_VACUNA, POST_VACUNA+2))
            print("El %s se va a las %.2f. " % (paciente, env.now))
            pacientes_atendidos = pacientes_atendidos+1
        else:
            print("El %s se va a las %.2f. " % (paciente, env.now))

# %%
# Procesos
def llegada_paciente(env, nombre, vacunacion):
    yield env.process(vacunacion.llega_paciente(nombre))
    with vacunacion.num_medicos.request() as medico:
        yield medico
        yield env.process(vacunacion.vacunar(nombre))
        env.process(vacunacion.salida(nombre))
        
def ejecutar_simulacion(env, num_medicos, num_pacientes, intervalo):
    global pacientes
    global ESPERA_INICIAL
    vacunacion = Centro_Vacunacion(env, num_medicos, num_pacientes)

    for i in range(5):
        env.process(llegada_paciente(env, 'Paciente-%d' % (i+1), vacunacion))
        
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+2))
        i+=1   
        env.process(llegada_paciente(env, 'Paciente-%d' % (i+1), vacunacion))
        pacientes = i+1

# %%
# Simulación
print("Iniciando Vacunación")
random.seed(77)

env = simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MEDICOS, NUM_PACIENTES, INTERVALO_LLEGADA))
env.run(until=NUM_PACIENTES*14)
# Out:
# Iniciando Vacunación
# El Paciente-1 llega a las 0.00.
# El Paciente-2 llega a las 0.00.
# El Paciente-3 llega a las 0.00.
# El Paciente-4 llega a las 0.00.
# El Paciente-5 llega a las 0.00.
# El Paciente-6 llega a las 14.00.
# El Paciente-1 entra a la fila a las 20.00.
# El Paciente-2 entra a la fila a las 20.00.
# El Paciente-3 entra a la fila a las 20.00.
# El Paciente-4 entra a la fila a las 20.00.
# El Paciente-5 entra a la fila a las 20.00.
# El Paciente-1 pasa a revisión en el padrón a las 20.00.
# El Paciente-2 pasa a revisión en el padrón a las 20.00.
# El Paciente-3 pasa a revisión en el padrón a las 20.00.
# El Paciente-4 pasa a revisión en el padrón a las 20.00.
# El Paciente-5 pasa a revisión en el padrón a las 20.00.
# El Paciente-2 empieza la vacunación a las 22.00.
# El Paciente-5 empieza la vacunación a las 22.00.
# El Paciente-1 empieza la vacunación a las 23.00.
# El Paciente-4 empieza la vacunación a las 23.00.
# El Paciente-3 empieza la vacunación a las 25.00.
# El Paciente-5 termina la vacunación a las 27.00.
# El Paciente-5 es llevado a la salida a las 27.00.
# El Paciente-7 llega a las 28.00.
# El Paciente-2 termina la vacunación a las 29.00.
# El Paciente-4 termina la vacunación a las 29.00.
# El Paciente-2 es llevado a la salida a las 29.00.
# El Paciente-4 es llevado a la salida a las 29.00.
# El Paciente-5 se va a las 30.00.
# El Paciente-2 se va a las 30.00.
# El Paciente-1 termina la vacunación a las 31.00.
# El Paciente-3 termina la vacunación a las 31.00.
# El Paciente-4 se va a las 31.00.
# El Paciente-1 es llevado a la salida a las 31.00.
# El Paciente-3 es llevado a la salida a las 31.00.
# El Paciente-3 se va a las 32.00.
# El Paciente-1 se va a las 33.00.
# El Paciente-6 entra a la fila a las 34.00.
# El Paciente-6 pasa a revisión en el padrón a las 34.00.
# El Paciente-6 empieza la vacunación a las 38.00.
# El Paciente-8 llega a las 43.00.
# El Paciente-6 termina la vacunación a las 47.00.
# El Paciente-6 es llevado a la salida a las 47.00.
# El Paciente-7 entra a la fila a las 48.00.
# El Paciente-6 se va a las 48.00.
# El Paciente-7 pasa a revisión en el padrón a las 48.00.
# El Paciente-7 empieza la vacunación a las 51.00.
# El Paciente-7 termina la vacunación a las 56.00.
# El Paciente-7 es llevado a la salida a las 56.00.
# El Paciente-7 se va a las 57.00.
# El Paciente-9 llega a las 58.00.
# El Paciente-8 entra a la fila a las 63.00.
# El Paciente-8 pasa a revisión en el padrón a las 63.00.
# El Paciente-8 empieza la vacunación a las 68.00.
# El Paciente-10 llega a las 71.00.
# El Paciente-8 termina la vacunación a las 77.00.
# El Paciente-8 es llevado a la salida a las 77.00.
# El Paciente-9 entra a la fila a las 78.00.
# El Paciente-9 pasa a revisión en el padrón a las 78.00.
# El Paciente-8 se va a las 80.00.
# El Paciente-9 empieza la vacunación a las 80.00.
# El Paciente-11 llega a las 88.00.
# El Paciente-9 termina la vacunación a las 90.00.
# El Paciente-9 es llevado a la salida a las 90.00.
# El Paciente-10 entra a la fila a las 91.00.
# El Paciente-9 se va a las 91.00.
# El Paciente-10 pasa a revisión en el padrón a las 91.00.
# !X!X!X! El Paciente-10 no puede vacunarse y se retira a las 95.00.
# El Paciente-10 se va a las 95.00.
# El Paciente-12 llega a las 105.00.
# El Paciente-11 entra a la fila a las 108.00.
# El Paciente-11 pasa a revisión en el padrón a las 108.00.
# El Paciente-11 empieza la vacunación a las 113.00.
# El Paciente-13 llega a las 117.00.
# El Paciente-11 termina la vacunación a las 118.00.
# El Paciente-11 es llevado a la salida a las 118.00.
# El Paciente-11 se va a las 119.00.
# El Paciente-12 entra a la fila a las 125.00.
# El Paciente-12 pasa a revisión en el padrón a las 125.00.
# El Paciente-12 empieza la vacunación a las 130.00.
# El Paciente-14 llega a las 133.00.
# El Paciente-13 entra a la fila a las 137.00.
# El Paciente-13 pasa a revisión en el padrón a las 137.00.
# El Paciente-12 termina la vacunación a las 140.00.
# El Paciente-12 es llevado a la salida a las 140.00.
# El Paciente-13 empieza la vacunación a las 141.00.
# El Paciente-12 se va a las 143.00.
# El Paciente-13 termina la vacunación a las 146.00.
# El Paciente-13 es llevado a la salida a las 146.00.
# El Paciente-13 se va a las 148.00.
# El Paciente-15 llega a las 149.00.
# El Paciente-14 entra a la fila a las 153.00.
# El Paciente-14 pasa a revisión en el padrón a las 153.00.
# El Paciente-14 empieza la vacunación a las 156.00.
# El Paciente-14 termina la vacunación a las 162.00.
# El Paciente-14 es llevado a la salida a las 162.00.
# El Paciente-16 llega a las 165.00.
# El Paciente-14 se va a las 165.00.
# El Paciente-15 entra a la fila a las 169.00.
# El Paciente-15 pasa a revisión en el padrón a las 169.00.
# El Paciente-15 empieza la vacunación a las 172.00.
# El Paciente-17 llega a las 180.00.
# El Paciente-15 termina la vacunación a las 180.00.
# El Paciente-15 es llevado a la salida a las 180.00.
# El Paciente-15 se va a las 181.00.
# El Paciente-16 entra a la fila a las 185.00.
# El Paciente-16 pasa a revisión en el padrón a las 185.00.
# El Paciente-16 empieza la vacunación a las 190.00.
# El Paciente-18 llega a las 192.00.
# El Paciente-17 entra a la fila a las 200.00.
# El Paciente-16 termina la vacunación a las 200.00.
# El Paciente-16 es llevado a la salida a las 200.00.
# El Paciente-17 pasa a revisión en el padrón a las 200.00.
# El Paciente-16 se va a las 203.00.
# El Paciente-19 llega a las 204.00.
# El Paciente-17 empieza la vacunación a las 205.00.
# El Paciente-18 entra a la fila a las 212.00.
# El Paciente-17 termina la vacunación a las 212.00.
# El Paciente-17 es llevado a la salida a las 212.00.
# El Paciente-18 pasa a revisión en el padrón a las 212.00.
# El Paciente-17 se va a las 215.00.
# El Paciente-20 llega a las 216.00.
# El Paciente-18 empieza la vacunación a las 217.00.
# El Paciente-19 entra a la fila a las 224.00.
# El Paciente-19 pasa a revisión en el padrón a las 224.00.
# El Paciente-19 empieza la vacunación a las 226.00.
# El Paciente-18 termina la vacunación a las 227.00.
# El Paciente-18 es llevado a la salida a las 227.00.
# El Paciente-21 llega a las 228.00.
# El Paciente-18 se va a las 229.00.
# El Paciente-19 termina la vacunación a las 232.00.
# El Paciente-19 es llevado a la salida a las 232.00.
# El Paciente-19 se va a las 233.00.
# El Paciente-20 entra a la fila a las 236.00.
# El Paciente-20 pasa a revisión en el padrón a las 236.00.
# El Paciente-20 empieza la vacunación a las 241.00.
# El Paciente-22 llega a las 244.00.
# El Paciente-21 entra a la fila a las 248.00.
# El Paciente-20 termina la vacunación a las 248.00.
# El Paciente-20 es llevado a la salida a las 248.00.
# El Paciente-21 pasa a revisión en el padrón a las 248.00.
# El Paciente-21 empieza la vacunación a las 250.00.
# El Paciente-20 se va a las 251.00.
# El Paciente-21 termina la vacunación a las 258.00.
# El Paciente-21 es llevado a la salida a las 258.00.
# El Paciente-23 llega a las 259.00.
# El Paciente-21 se va a las 259.00.
# El Paciente-22 entra a la fila a las 264.00.
# El Paciente-22 pasa a revisión en el padrón a las 264.00.
# El Paciente-22 empieza la vacunación a las 266.00.
# El Paciente-24 llega a las 271.00.
# El Paciente-22 termina la vacunación a las 272.00.
# El Paciente-22 es llevado a la salida a las 272.00.
# El Paciente-22 se va a las 275.00.
# El Paciente-23 entra a la fila a las 279.00.
# El Paciente-23 pasa a revisión en el padrón a las 279.00.
# El Paciente-23 empieza la vacunación a las 281.00.
# El Paciente-25 llega a las 283.00.
# El Paciente-23 termina la vacunación a las 289.00.
# El Paciente-23 es llevado a la salida a las 289.00.
# El Paciente-23 se va a las 290.00.
# El Paciente-24 entra a la fila a las 291.00.
# El Paciente-24 pasa a revisión en el padrón a las 291.00.
# El Paciente-24 empieza la vacunación a las 294.00.
# El Paciente-26 llega a las 298.00.
# El Paciente-24 termina la vacunación a las 301.00.
# El Paciente-24 es llevado a la salida a las 301.00.
# El Paciente-24 se va a las 302.00.
# El Paciente-25 entra a la fila a las 303.00.
# El Paciente-25 pasa a revisión en el padrón a las 303.00.
# El Paciente-25 empieza la vacunación a las 306.00.
# El Paciente-27 llega a las 311.00.
# El Paciente-25 termina la vacunación a las 312.00.
# El Paciente-25 es llevado a la salida a las 312.00.
# El Paciente-25 se va a las 313.00.
# El Paciente-26 entra a la fila a las 318.00.
# El Paciente-26 pasa a revisión en el padrón a las 318.00.
# El Paciente-28 llega a las 323.00.
# El Paciente-26 empieza la vacunación a las 323.00.
# El Paciente-27 entra a la fila a las 331.00.
# El Paciente-27 pasa a revisión en el padrón a las 331.00.
# El Paciente-26 termina la vacunación a las 333.00.
# El Paciente-26 es llevado a la salida a las 333.00.
# El Paciente-26 se va a las 335.00.
# El Paciente-27 empieza la vacunación a las 336.00.
# El Paciente-29 llega a las 339.00.
# El Paciente-28 entra a la fila a las 343.00.
# El Paciente-28 pasa a revisión en el padrón a las 343.00.
# El Paciente-27 termina la vacunación a las 345.00.
# El Paciente-28 empieza la vacunación a las 345.00.
# El Paciente-27 es llevado a la salida a las 345.00.
# El Paciente-27 se va a las 348.00.
# El Paciente-30 llega a las 353.00.
# El Paciente-28 termina la vacunación a las 353.00.
# El Paciente-28 es llevado a la salida a las 353.00.
# El Paciente-28 se va a las 355.00.
# El Paciente-29 entra a la fila a las 359.00.
# El Paciente-29 pasa a revisión en el padrón a las 359.00.
# El Paciente-29 empieza la vacunación a las 363.00.
# El Paciente-31 llega a las 368.00.
# El Paciente-29 termina la vacunación a las 370.00.
# El Paciente-29 es llevado a la salida a las 370.00.
# El Paciente-29 se va a las 371.00.
# El Paciente-30 entra a la fila a las 373.00.
# El Paciente-30 pasa a revisión en el padrón a las 373.00.
# El Paciente-30 empieza la vacunación a las 378.00.
# El Paciente-32 llega a las 383.00.
# El Paciente-30 termina la vacunación a las 383.00.
# El Paciente-30 es llevado a la salida a las 383.00.
# El Paciente-30 se va a las 384.00.
# El Paciente-31 entra a la fila a las 388.00.
# El Paciente-31 pasa a revisión en el padrón a las 388.00.
# !X!X!X! El Paciente-31 no puede vacunarse y se retira a las 391.00.
# El Paciente-31 se va a las 391.00.
# El Paciente-33 llega a las 395.00.
# El Paciente-32 entra a la fila a las 403.00.
# El Paciente-32 pasa a revisión en el padrón a las 403.00.
# El Paciente-32 empieza la vacunación a las 405.00.
# El Paciente-34 llega a las 407.00.
# El Paciente-32 termina la vacunación a las 414.00.
# El Paciente-32 es llevado a la salida a las 414.00.
# El Paciente-33 entra a la fila a las 415.00.
# El Paciente-33 pasa a revisión en el padrón a las 415.00.
# El Paciente-32 se va a las 417.00.
# El Paciente-35 llega a las 420.00.
# El Paciente-33 empieza la vacunación a las 420.00.
# El Paciente-33 termina la vacunación a las 425.00.
# El Paciente-33 es llevado a la salida a las 425.00.
# El Paciente-34 entra a la fila a las 427.00.
# El Paciente-34 pasa a revisión en el padrón a las 427.00.
# El Paciente-33 se va a las 428.00.
# El Paciente-34 empieza la vacunación a las 431.00.
# El Paciente-36 llega a las 433.00.
# El Paciente-34 termina la vacunación a las 439.00.
# El Paciente-34 es llevado a la salida a las 439.00.
# El Paciente-35 entra a la fila a las 440.00.
# El Paciente-35 pasa a revisión en el padrón a las 440.00.
# El Paciente-34 se va a las 442.00.
# El Paciente-35 empieza la vacunación a las 445.00.
# El Paciente-37 llega a las 448.00.
# El Paciente-35 termina la vacunación a las 451.00.
# El Paciente-35 es llevado a la salida a las 451.00.
# El Paciente-36 entra a la fila a las 453.00.
# El Paciente-35 se va a las 453.00.
# El Paciente-36 pasa a revisión en el padrón a las 453.00.
# El Paciente-36 empieza la vacunación a las 457.00.
# El Paciente-36 termina la vacunación a las 462.00.
# El Paciente-36 es llevado a la salida a las 462.00.
# El Paciente-38 llega a las 465.00.
# El Paciente-36 se va a las 465.00.
# El Paciente-37 entra a la fila a las 468.00.
# El Paciente-37 pasa a revisión en el padrón a las 468.00.
# El Paciente-37 empieza la vacunación a las 471.00.
# El Paciente-37 termina la vacunación a las 478.00.
# El Paciente-37 es llevado a la salida a las 478.00.
# El Paciente-39 llega a las 479.00.
# El Paciente-37 se va a las 480.00.
# El Paciente-38 entra a la fila a las 485.00.
# El Paciente-38 pasa a revisión en el padrón a las 485.00.
# El Paciente-38 empieza la vacunación a las 490.00.
# El Paciente-40 llega a las 496.00.
# El Paciente-39 entra a la fila a las 499.00.
# El Paciente-39 pasa a revisión en el padrón a las 499.00.
# El Paciente-38 termina la vacunación a las 500.00.
# El Paciente-38 es llevado a la salida a las 500.00.
# El Paciente-38 se va a las 503.00.
# El Paciente-39 empieza la vacunación a las 504.00.
# El Paciente-41 llega a las 513.00.
# El Paciente-39 termina la vacunación a las 513.00.
# El Paciente-39 es llevado a la salida a las 513.00.
# El Paciente-39 se va a las 515.00.
# El Paciente-40 entra a la fila a las 516.00.
# El Paciente-40 pasa a revisión en el padrón a las 516.00.
# El Paciente-40 empieza la vacunación a las 520.00.
# El Paciente-40 termina la vacunación a las 525.00.
# El Paciente-40 es llevado a la salida a las 525.00.
# El Paciente-40 se va a las 527.00.
# El Paciente-42 llega a las 528.00.
# El Paciente-41 entra a la fila a las 533.00.
# El Paciente-41 pasa a revisión en el padrón a las 533.00.
# El Paciente-41 empieza la vacunación a las 536.00.
# El Paciente-41 termina la vacunación a las 542.00.
# El Paciente-41 es llevado a la salida a las 542.00.
# El Paciente-41 se va a las 544.00.
# El Paciente-43 llega a las 545.00.
# El Paciente-42 entra a la fila a las 548.00.
# El Paciente-42 pasa a revisión en el padrón a las 548.00.
# El Paciente-42 empieza la vacunación a las 551.00.
# El Paciente-42 termina la vacunación a las 560.00.
# El Paciente-42 es llevado a la salida a las 560.00.
# El Paciente-44 llega a las 562.00.
# El Paciente-42 se va a las 563.00.
# El Paciente-43 entra a la fila a las 565.00.
# El Paciente-43 pasa a revisión en el padrón a las 565.00.
# El Paciente-43 empieza la vacunación a las 567.00.
# El Paciente-43 termina la vacunación a las 576.00.
# El Paciente-43 es llevado a la salida a las 576.00.
# El Paciente-43 se va a las 577.00.
# El Paciente-45 llega a las 578.00.
# El Paciente-44 entra a la fila a las 582.00.
# El Paciente-44 pasa a revisión en el padrón a las 582.00.
# El Paciente-44 empieza la vacunación a las 584.00.
# El Paciente-44 termina la vacunación a las 594.00.
# El Paciente-44 es llevado a la salida a las 594.00.
# El Paciente-46 llega a las 595.00.
# El Paciente-44 se va a las 597.00.
# El Paciente-45 entra a la fila a las 598.00.
# El Paciente-45 pasa a revisión en el padrón a las 598.00.
# El Paciente-45 empieza la vacunación a las 601.00.
# El Paciente-47 llega a las 608.00.
# El Paciente-45 termina la vacunación a las 611.00.
# El Paciente-45 es llevado a la salida a las 611.00.
# El Paciente-45 se va a las 612.00.
# El Paciente-46 entra a la fila a las 615.00.
# El Paciente-46 pasa a revisión en el padrón a las 615.00.
# El Paciente-46 empieza la vacunación a las 620.00.
# El Paciente-48 llega a las 622.00.
# El Paciente-46 termina la vacunación a las 625.00.
# El Paciente-46 es llevado a la salida a las 625.00.
# El Paciente-46 se va a las 627.00.
# El Paciente-47 entra a la fila a las 628.00.
# El Paciente-47 pasa a revisión en el padrón a las 628.00.
# El Paciente-47 empieza la vacunación a las 632.00.
# El Paciente-49 llega a las 639.00.
# El Paciente-47 termina la vacunación a las 640.00.
# El Paciente-47 es llevado a la salida a las 640.00.
# El Paciente-48 entra a la fila a las 642.00.
# El Paciente-48 pasa a revisión en el padrón a las 642.00.
# El Paciente-47 se va a las 643.00.
# !X!X!X! El Paciente-48 no puede vacunarse y se retira a las 644.00.
# El Paciente-48 se va a las 644.00.
# El Paciente-50 llega a las 656.00.
# El Paciente-49 entra a la fila a las 659.00.
# El Paciente-49 pasa a revisión en el padrón a las 659.00.
# El Paciente-49 empieza la vacunación a las 662.00.
# El Paciente-51 llega a las 668.00.
# El Paciente-49 termina la vacunación a las 670.00.
# El Paciente-49 es llevado a la salida a las 670.00.
# El Paciente-49 se va a las 673.00.
# El Paciente-50 entra a la fila a las 676.00.
# El Paciente-50 pasa a revisión en el padrón a las 676.00.
# El Paciente-50 empieza la vacunación a las 681.00.
# El Paciente-52 llega a las 683.00.
# El Paciente-50 termina la vacunación a las 686.00.
# El Paciente-50 es llevado a la salida a las 686.00.
# El Paciente-50 se va a las 687.00.
# El Paciente-51 entra a la fila a las 688.00.
# El Paciente-51 pasa a revisión en el padrón a las 688.00.
# El Paciente-51 empieza la vacunación a las 691.00.
# El Paciente-53 llega a las 695.00.
# El Paciente-51 termina la vacunación a las 696.00.
# El Paciente-51 es llevado a la salida a las 696.00.
# El Paciente-51 se va a las 698.00.
# El Paciente-52 entra a la fila a las 703.00.
# El Paciente-52 pasa a revisión en el padrón a las 703.00.
# El Paciente-52 empieza la vacunación a las 707.00.
# El Paciente-54 llega a las 712.00.
# El Paciente-53 entra a la fila a las 715.00.
# El Paciente-53 pasa a revisión en el padrón a las 715.00.
# El Paciente-52 termina la vacunación a las 717.00.
# El Paciente-53 empieza la vacunación a las 717.00.
# El Paciente-52 es llevado a la salida a las 717.00.
# El Paciente-52 se va a las 718.00.
# El Paciente-53 termina la vacunación a las 722.00.
# El Paciente-53 es llevado a la salida a las 722.00.
# El Paciente-55 llega a las 725.00.
# El Paciente-53 se va a las 725.00.
# El Paciente-54 entra a la fila a las 732.00.
# El Paciente-54 pasa a revisión en el padrón a las 732.00.
# El Paciente-54 empieza la vacunación a las 734.00.
# El Paciente-54 termina la vacunación a las 740.00.
# El Paciente-54 es llevado a la salida a las 740.00.
# El Paciente-56 llega a las 742.00.
# El Paciente-54 se va a las 743.00.
# El Paciente-55 entra a la fila a las 745.00.
# El Paciente-55 pasa a revisión en el padrón a las 745.00.
# El Paciente-55 empieza la vacunación a las 749.00.
# El Paciente-55 termina la vacunación a las 756.00.
# El Paciente-55 es llevado a la salida a las 756.00.
# El Paciente-57 llega a las 757.00.
# El Paciente-55 se va a las 758.00.
# El Paciente-56 entra a la fila a las 762.00.
# El Paciente-56 pasa a revisión en el padrón a las 762.00.
# El Paciente-56 empieza la vacunación a las 767.00.
# El Paciente-58 llega a las 770.00.
# El Paciente-56 termina la vacunación a las 776.00.
# El Paciente-56 es llevado a la salida a las 776.00.
# El Paciente-57 entra a la fila a las 777.00.
# El Paciente-57 pasa a revisión en el padrón a las 777.00.
# El Paciente-56 se va a las 779.00.
# El Paciente-57 empieza la vacunación a las 780.00.
# El Paciente-59 llega a las 785.00.
# El Paciente-57 termina la vacunación a las 788.00.
# El Paciente-57 es llevado a la salida a las 788.00.
# El Paciente-57 se va a las 789.00.
# El Paciente-58 entra a la fila a las 790.00.
# El Paciente-58 pasa a revisión en el padrón a las 790.00.
# El Paciente-58 empieza la vacunación a las 794.00.
# El Paciente-60 llega a las 802.00.
# El Paciente-58 termina la vacunación a las 804.00.
# El Paciente-58 es llevado a la salida a las 804.00.
# El Paciente-59 entra a la fila a las 805.00.
# El Paciente-59 pasa a revisión en el padrón a las 805.00.
# El Paciente-58 se va a las 806.00.
# El Paciente-59 empieza la vacunación a las 810.00.
# El Paciente-59 termina la vacunación a las 816.00.
# El Paciente-59 es llevado a la salida a las 816.00.
# El Paciente-61 llega a las 819.00.
# El Paciente-59 se va a las 819.00.
# El Paciente-60 entra a la fila a las 822.00.
# El Paciente-60 pasa a revisión en el padrón a las 822.00.
# El Paciente-60 empieza la vacunación a las 825.00.
# El Paciente-60 termina la vacunación a las 832.00.
# El Paciente-60 es llevado a la salida a las 832.00.
# El Paciente-60 se va a las 834.00.
# El Paciente-62 llega a las 835.00.
# El Paciente-61 entra a la fila a las 839.00.
# El Paciente-61 pasa a revisión en el padrón a las 839.00.
# El Paciente-61 empieza la vacunación a las 843.00.
# El Paciente-63 llega a las 848.00.
# El Paciente-61 termina la vacunación a las 853.00.
# El Paciente-61 es llevado a la salida a las 853.00.
# El Paciente-62 entra a la fila a las 855.00.
# El Paciente-61 se va a las 855.00.
# El Paciente-62 pasa a revisión en el padrón a las 855.00.
# El Paciente-62 empieza la vacunación a las 860.00.
# El Paciente-64 llega a las 861.00.
# El Paciente-62 termina la vacunación a las 867.00.
# El Paciente-62 es llevado a la salida a las 867.00.
# El Paciente-63 entra a la fila a las 868.00.
# El Paciente-63 pasa a revisión en el padrón a las 868.00.
# El Paciente-62 se va a las 869.00.
# El Paciente-63 empieza la vacunación a las 870.00.
# El Paciente-65 llega a las 875.00.
# El Paciente-63 termina la vacunación a las 878.00.
# El Paciente-63 es llevado a la salida a las 878.00.
# El Paciente-64 entra a la fila a las 881.00.
# El Paciente-63 se va a las 881.00.
# El Paciente-64 pasa a revisión en el padrón a las 881.00.
# El Paciente-64 empieza la vacunación a las 885.00.
# El Paciente-66 llega a las 891.00.
# El Paciente-64 termina la vacunación a las 892.00.
# El Paciente-64 es llevado a la salida a las 892.00.
# El Paciente-64 se va a las 893.00.
# El Paciente-65 entra a la fila a las 895.00.
# El Paciente-65 pasa a revisión en el padrón a las 895.00.
# El Paciente-65 empieza la vacunación a las 900.00.
# El Paciente-67 llega a las 904.00.
# El Paciente-65 termina la vacunación a las 908.00.
# El Paciente-65 es llevado a la salida a las 908.00.
# El Paciente-66 entra a la fila a las 911.00.
# El Paciente-65 se va a las 911.00.
# El Paciente-66 pasa a revisión en el padrón a las 911.00.
# El Paciente-66 empieza la vacunación a las 916.00.
# El Paciente-68 llega a las 920.00.
# El Paciente-67 entra a la fila a las 924.00.
# El Paciente-67 pasa a revisión en el padrón a las 924.00.
# El Paciente-66 termina la vacunación a las 926.00.
# El Paciente-66 es llevado a la salida a las 926.00.
# El Paciente-67 empieza la vacunación a las 929.00.
# El Paciente-66 se va a las 929.00.
# El Paciente-69 llega a las 935.00.
# El Paciente-67 termina la vacunación a las 936.00.
# El Paciente-67 es llevado a la salida a las 936.00.
# El Paciente-67 se va a las 938.00.
# El Paciente-68 entra a la fila a las 940.00.
# El Paciente-68 pasa a revisión en el padrón a las 940.00.
# El Paciente-68 empieza la vacunación a las 943.00.
# El Paciente-70 llega a las 950.00.
# El Paciente-68 termina la vacunación a las 951.00.
# El Paciente-68 es llevado a la salida a las 951.00.
# El Paciente-68 se va a las 954.00.
# El Paciente-69 entra a la fila a las 955.00.
# El Paciente-69 pasa a revisión en el padrón a las 955.00.
# El Paciente-69 empieza la vacunación a las 959.00.
# El Paciente-69 termina la vacunación a las 964.00.
# El Paciente-69 es llevado a la salida a las 964.00.
# El Paciente-71 llega a las 965.00.
# El Paciente-69 se va a las 967.00.
# El Paciente-70 entra a la fila a las 970.00.
# El Paciente-70 pasa a revisión en el padrón a las 970.00.
# El Paciente-70 empieza la vacunación a las 975.00.
# El Paciente-72 llega a las 979.00.
# El Paciente-70 termina la vacunación a las 984.00.
# El Paciente-70 es llevado a la salida a las 984.00.
# El Paciente-71 entra a la fila a las 985.00.
# El Paciente-71 pasa a revisión en el padrón a las 985.00.
# El Paciente-70 se va a las 987.00.
# El Paciente-71 empieza la vacunación a las 987.00.
# El Paciente-73 llega a las 994.00.
# El Paciente-71 termina la vacunación a las 996.00.
# El Paciente-71 es llevado a la salida a las 996.00.
# El Paciente-71 se va a las 998.00.
# El Paciente-72 entra a la fila a las 999.00.
# El Paciente-72 pasa a revisión en el padrón a las 999.00.
# El Paciente-72 empieza la vacunación a las 1003.00.
# El Paciente-74 llega a las 1006.00.
# El Paciente-72 termina la vacunación a las 1013.00.
# El Paciente-72 es llevado a la salida a las 1013.00.
# El Paciente-73 entra a la fila a las 1014.00.
# El Paciente-73 pasa a revisión en el padrón a las 1014.00.
# El Paciente-72 se va a las 1016.00.
# El Paciente-73 empieza la vacunación a las 1018.00.
# El Paciente-75 llega a las 1020.00.
# El Paciente-73 termina la vacunación a las 1025.00.
# El Paciente-73 es llevado a la salida a las 1025.00.
# El Paciente-74 entra a la fila a las 1026.00.
# El Paciente-73 se va a las 1026.00.
# El Paciente-74 pasa a revisión en el padrón a las 1026.00.
# El Paciente-74 empieza la vacunación a las 1029.00.
# El Paciente-76 llega a las 1033.00.
# El Paciente-74 termina la vacunación a las 1035.00.
# El Paciente-74 es llevado a la salida a las 1035.00.
# El Paciente-74 se va a las 1037.00.
# El Paciente-75 entra a la fila a las 1040.00.
# El Paciente-75 pasa a revisión en el padrón a las 1040.00.
# El Paciente-75 empieza la vacunación a las 1044.00.
# El Paciente-77 llega a las 1045.00.
# El Paciente-75 termina la vacunación a las 1051.00.
# El Paciente-75 es llevado a la salida a las 1051.00.
# El Paciente-75 se va a las 1052.00.
# El Paciente-76 entra a la fila a las 1053.00.
# El Paciente-76 pasa a revisión en el padrón a las 1053.00.
# El Paciente-76 empieza la vacunación a las 1057.00.
# El Paciente-78 llega a las 1059.00.
# El Paciente-76 termina la vacunación a las 1063.00.
# El Paciente-76 es llevado a la salida a las 1063.00.
# El Paciente-77 entra a la fila a las 1065.00.
# El Paciente-76 se va a las 1065.00.
# El Paciente-77 pasa a revisión en el padrón a las 1065.00.
# El Paciente-77 empieza la vacunación a las 1067.00.
# El Paciente-79 llega a las 1072.00.
# El Paciente-77 termina la vacunación a las 1075.00.
# El Paciente-77 es llevado a la salida a las 1075.00.
# El Paciente-77 se va a las 1076.00.
# El Paciente-78 entra a la fila a las 1079.00.
# El Paciente-78 pasa a revisión en el padrón a las 1079.00.
# El Paciente-78 empieza la vacunación a las 1084.00.
# El Paciente-80 llega a las 1088.00.
# El Paciente-78 termina la vacunación a las 1090.00.
# El Paciente-78 es llevado a la salida a las 1090.00.
# El Paciente-79 entra a la fila a las 1092.00.
# El Paciente-79 pasa a revisión en el padrón a las 1092.00.
# El Paciente-78 se va a las 1093.00.
# El Paciente-79 empieza la vacunación a las 1094.00.
# El Paciente-81 llega a las 1101.00.
# El Paciente-79 termina la vacunación a las 1102.00.
# El Paciente-79 es llevado a la salida a las 1102.00.
# El Paciente-79 se va a las 1105.00.
# El Paciente-80 entra a la fila a las 1108.00.
# El Paciente-80 pasa a revisión en el padrón a las 1108.00.
# El Paciente-80 empieza la vacunación a las 1110.00.
# El Paciente-82 llega a las 1113.00.
# El Paciente-80 termina la vacunación a las 1115.00.
# El Paciente-80 es llevado a la salida a las 1115.00.
# El Paciente-80 se va a las 1116.00.
# El Paciente-81 entra a la fila a las 1121.00.
# El Paciente-81 pasa a revisión en el padrón a las 1121.00.
# El Paciente-83 llega a las 1125.00.
# El Paciente-81 empieza la vacunación a las 1125.00.
# El Paciente-82 entra a la fila a las 1133.00.
# El Paciente-81 termina la vacunación a las 1133.00.
# El Paciente-81 es llevado a la salida a las 1133.00.
# El Paciente-82 pasa a revisión en el padrón a las 1133.00.
# El Paciente-81 se va a las 1135.00.
# El Paciente-82 empieza la vacunación a las 1135.00.
# El Paciente-84 llega a las 1140.00.
# El Paciente-82 termina la vacunación a las 1141.00.
# El Paciente-82 es llevado a la salida a las 1141.00.
# El Paciente-82 se va a las 1143.00.
# El Paciente-83 entra a la fila a las 1145.00.
# El Paciente-83 pasa a revisión en el padrón a las 1145.00.
# El Paciente-83 empieza la vacunación a las 1148.00.
# El Paciente-85 llega a las 1156.00.
# El Paciente-83 termina la vacunación a las 1157.00.
# El Paciente-83 es llevado a la salida a las 1157.00.
# El Paciente-83 se va a las 1158.00.
# El Paciente-84 entra a la fila a las 1160.00.
# El Paciente-84 pasa a revisión en el padrón a las 1160.00.
# El Paciente-84 empieza la vacunación a las 1163.00.
# El Paciente-84 termina la vacunación a las 1169.00.
# El Paciente-84 es llevado a la salida a las 1169.00.
# El Paciente-84 se va a las 1172.00.
# El Paciente-86 llega a las 1173.00.
# El Paciente-85 entra a la fila a las 1176.00.
# El Paciente-85 pasa a revisión en el padrón a las 1176.00.
# El Paciente-85 empieza la vacunación a las 1180.00.
# El Paciente-87 llega a las 1186.00.
# El Paciente-85 termina la vacunación a las 1187.00.
# El Paciente-85 es llevado a la salida a las 1187.00.
# El Paciente-85 se va a las 1190.00.
# El Paciente-86 entra a la fila a las 1193.00.
# El Paciente-86 pasa a revisión en el padrón a las 1193.00.
# El Paciente-86 empieza la vacunación a las 1195.00.
# El Paciente-88 llega a las 1198.00.
# El Paciente-86 termina la vacunación a las 1204.00.
# El Paciente-86 es llevado a la salida a las 1204.00.
# El Paciente-87 entra a la fila a las 1206.00.
# El Paciente-86 se va a las 1206.00.
# El Paciente-87 pasa a revisión en el padrón a las 1206.00.
# El Paciente-89 llega a las 1211.00.
# El Paciente-87 empieza la vacunación a las 1211.00.
# El Paciente-88 entra a la fila a las 1218.00.
# El Paciente-88 pasa a revisión en el padrón a las 1218.00.
# El Paciente-87 termina la vacunación a las 1221.00.
# El Paciente-88 empieza la vacunación a las 1221.00.
# El Paciente-87 es llevado a la salida a las 1221.00.
# El Paciente-87 se va a las 1224.00.
# El Paciente-88 termina la vacunación a las 1226.00.
# El Paciente-88 es llevado a la salida a las 1226.00.
# El Paciente-90 llega a las 1228.00.
# El Paciente-88 se va a las 1228.00.
# El Paciente-89 entra a la fila a las 1231.00.
# El Paciente-89 pasa a revisión en el padrón a las 1231.00.
# El Paciente-89 empieza la vacunación a las 1236.00.
# El Paciente-91 llega a las 1243.00.
# El Paciente-89 termina la vacunación a las 1246.00.
# El Paciente-89 es llevado a la salida a las 1246.00.
# El Paciente-90 entra a la fila a las 1248.00.
# El Paciente-90 pasa a revisión en el padrón a las 1248.00.
# El Paciente-89 se va a las 1249.00.
# El Paciente-90 empieza la vacunación a las 1250.00.
# El Paciente-90 termina la vacunación a las 1257.00.
# El Paciente-90 es llevado a la salida a las 1257.00.
# El Paciente-92 llega a las 1258.00.
# El Paciente-90 se va a las 1258.00.
# El Paciente-91 entra a la fila a las 1263.00.
# El Paciente-91 pasa a revisión en el padrón a las 1263.00.
# El Paciente-91 empieza la vacunación a las 1268.00.
# El Paciente-93 llega a las 1270.00.
# El Paciente-91 termina la vacunación a las 1274.00.
# El Paciente-91 es llevado a la salida a las 1274.00.
# El Paciente-91 se va a las 1277.00.
# El Paciente-92 entra a la fila a las 1278.00.
# El Paciente-92 pasa a revisión en el padrón a las 1278.00.
# El Paciente-92 empieza la vacunación a las 1282.00.
# El Paciente-94 llega a las 1284.00.
# El Paciente-92 termina la vacunación a las 1289.00.
# El Paciente-92 es llevado a la salida a las 1289.00.
# El Paciente-93 entra a la fila a las 1290.00.
# El Paciente-93 pasa a revisión en el padrón a las 1290.00.
# El Paciente-92 se va a las 1291.00.
# !X!X!X! El Paciente-93 no puede vacunarse y se retira a las 1294.00.
# El Paciente-93 se va a las 1294.00.
# El Paciente-95 llega a las 1299.00.
# El Paciente-94 entra a la fila a las 1304.00.
# El Paciente-94 pasa a revisión en el padrón a las 1304.00.
# El Paciente-94 empieza la vacunación a las 1306.00.
# El Paciente-94 termina la vacunación a las 1311.00.
# El Paciente-94 es llevado a la salida a las 1311.00.
# El Paciente-96 llega a las 1312.00.
# El Paciente-94 se va a las 1314.00.
# El Paciente-95 entra a la fila a las 1319.00.
# El Paciente-95 pasa a revisión en el padrón a las 1319.00.
# !X!X!X! El Paciente-95 no puede vacunarse y se retira a las 1321.00.
# El Paciente-95 se va a las 1321.00.
# El Paciente-97 llega a las 1325.00.
# El Paciente-96 entra a la fila a las 1332.00.
# El Paciente-96 pasa a revisión en el padrón a las 1332.00.
# El Paciente-96 empieza la vacunación a las 1335.00.
# El Paciente-98 llega a las 1340.00.
# El Paciente-97 entra a la fila a las 1345.00.
# El Paciente-96 termina la vacunación a las 1345.00.
# El Paciente-96 es llevado a la salida a las 1345.00.
# El Paciente-97 pasa a revisión en el padrón a las 1345.00.
# El Paciente-96 se va a las 1348.00.
# El Paciente-97 empieza la vacunación a las 1348.00.
# El Paciente-99 llega a las 1357.00.
# El Paciente-97 termina la vacunación a las 1357.00.
# El Paciente-97 es llevado a la salida a las 1357.00.
# El Paciente-98 entra a la fila a las 1360.00.
# El Paciente-97 se va a las 1360.00.
# El Paciente-98 pasa a revisión en el padrón a las 1360.00.
# !X!X!X! El Paciente-98 no puede vacunarse y se retira a las 1363.00.
# El Paciente-98 se va a las 1363.00.
# El Paciente-100 llega a las 1372.00.
# El Paciente-99 entra a la fila a las 1377.00.
# El Paciente-99 pasa a revisión en el padrón a las 1377.00.
# El Paciente-99 empieza la vacunación a las 1380.00.
# El Paciente-99 termina la vacunación a las 1385.00.
# El Paciente-99 es llevado a la salida a las 1385.00.
# El Paciente-101 llega a las 1386.00.
# El Paciente-99 se va a las 1388.00.
# El Paciente-100 entra a la fila a las 1392.00.
# El Paciente-100 pasa a revisión en el padrón a las 1392.00.
# El Paciente-100 empieza la vacunación a las 1397.00.
# El Paciente-102 llega a las 1400.00.
# El Paciente-100 termina la vacunación a las 1403.00.
# El Paciente-100 es llevado a la salida a las 1403.00.
# El Paciente-100 se va a las 1405.00.
# El Paciente-101 entra a la fila a las 1406.00.
# El Paciente-101 pasa a revisión en el padrón a las 1406.00.
# El Paciente-101 empieza la vacunación a las 1409.00.
# El Paciente-103 llega a las 1415.00.
# El Paciente-101 termina la vacunación a las 1415.00.
# El Paciente-101 es llevado a la salida a las 1415.00.
# El Paciente-101 se va a las 1416.00.
# El Paciente-102 entra a la fila a las 1420.00.
# El Paciente-102 pasa a revisión en el padrón a las 1420.00.
# El Paciente-102 empieza la vacunación a las 1423.00.
# El Paciente-104 llega a las 1427.00.
# El Paciente-102 termina la vacunación a las 1428.00.
# El Paciente-102 es llevado a la salida a las 1428.00.
# El Paciente-102 se va a las 1430.00.
# El Paciente-103 entra a la fila a las 1435.00.
# El Paciente-103 pasa a revisión en el padrón a las 1435.00.
# El Paciente-103 empieza la vacunación a las 1440.00.
# El Paciente-105 llega a las 1441.00.
# El Paciente-104 entra a la fila a las 1447.00.
# El Paciente-104 pasa a revisión en el padrón a las 1447.00.
# El Paciente-103 termina la vacunación a las 1449.00.
# El Paciente-103 es llevado a la salida a las 1449.00.
# El Paciente-104 empieza la vacunación a las 1452.00.
# El Paciente-103 se va a las 1452.00.
# El Paciente-106 llega a las 1453.00.
# El Paciente-104 termina la vacunación a las 1457.00.
# El Paciente-104 es llevado a la salida a las 1457.00.
# El Paciente-104 se va a las 1459.00.
# El Paciente-105 entra a la fila a las 1461.00.
# El Paciente-105 pasa a revisión en el padrón a las 1461.00.
# El Paciente-105 empieza la vacunación a las 1464.00.
# El Paciente-107 llega a las 1469.00.
# El Paciente-105 termina la vacunación a las 1471.00.
# El Paciente-105 es llevado a la salida a las 1471.00.
# El Paciente-105 se va a las 1472.00.
# El Paciente-106 entra a la fila a las 1473.00.
# El Paciente-106 pasa a revisión en el padrón a las 1473.00.
# El Paciente-106 empieza la vacunación a las 1476.00.
# El Paciente-108 llega a las 1484.00.
# El Paciente-106 termina la vacunación a las 1485.00.
# El Paciente-106 es llevado a la salida a las 1485.00.
# El Paciente-106 se va a las 1487.00.
# El Paciente-107 entra a la fila a las 1489.00.
# El Paciente-107 pasa a revisión en el padrón a las 1489.00.
# El Paciente-107 empieza la vacunación a las 1493.00.
# El Paciente-109 llega a las 1498.00.
# El Paciente-107 termina la vacunación a las 1502.00.
# El Paciente-107 es llevado a la salida a las 1502.00.
# El Paciente-107 se va a las 1503.00.
# El Paciente-108 entra a la fila a las 1504.00.
# El Paciente-108 pasa a revisión en el padrón a las 1504.00.
# El Paciente-108 empieza la vacunación a las 1508.00.
# El Paciente-110 llega a las 1512.00.
# El Paciente-108 termina la vacunación a las 1515.00.
# El Paciente-108 es llevado a la salida a las 1515.00.
# El Paciente-108 se va a las 1516.00.
# El Paciente-109 entra a la fila a las 1518.00.
# El Paciente-109 pasa a revisión en el padrón a las 1518.00.
# El Paciente-109 empieza la vacunación a las 1522.00.
# El Paciente-111 llega a las 1527.00.
# El Paciente-110 entra a la fila a las 1532.00.
# El Paciente-109 termina la vacunación a las 1532.00.
# El Paciente-109 es llevado a la salida a las 1532.00.
# El Paciente-110 pasa a revisión en el padrón a las 1532.00.
# El Paciente-109 se va a las 1533.00.
# El Paciente-110 empieza la vacunación a las 1534.00.
# El Paciente-112 llega a las 1541.00.
# El Paciente-110 termina la vacunación a las 1543.00.
# El Paciente-110 es llevado a la salida a las 1543.00.
# El Paciente-110 se va a las 1545.00.
# El Paciente-111 entra a la fila a las 1547.00.
# El Paciente-111 pasa a revisión en el padrón a las 1547.00.
# El Paciente-111 empieza la vacunación a las 1550.00.
# El Paciente-113 llega a las 1558.00.
# El Paciente-111 termina la vacunación a las 1560.00.
# El Paciente-111 es llevado a la salida a las 1560.00.
# El Paciente-112 entra a la fila a las 1561.00.
# El Paciente-111 se va a las 1561.00.
# El Paciente-112 pasa a revisión en el padrón a las 1561.00.
# El Paciente-112 empieza la vacunación a las 1563.00.
# El Paciente-112 termina la vacunación a las 1573.00.
# El Paciente-112 es llevado a la salida a las 1573.00.
# El Paciente-114 llega a las 1575.00.
# El Paciente-112 se va a las 1576.00.
# El Paciente-113 entra a la fila a las 1578.00.
# El Paciente-113 pasa a revisión en el padrón a las 1578.00.
# El Paciente-113 empieza la vacunación a las 1583.00.
# El Paciente-113 termina la vacunación a las 1589.00.
# El Paciente-113 es llevado a la salida a las 1589.00.
# El Paciente-115 llega a las 1590.00.
# El Paciente-113 se va a las 1591.00.
# El Paciente-114 entra a la fila a las 1595.00.
# El Paciente-114 pasa a revisión en el padrón a las 1595.00.
# El Paciente-114 empieza la vacunación a las 1599.00.
# El Paciente-116 llega a las 1603.00.
# El Paciente-114 termina la vacunación a las 1604.00.
# El Paciente-114 es llevado a la salida a las 1604.00.
# El Paciente-114 se va a las 1606.00.
# El Paciente-115 entra a la fila a las 1610.00.
# El Paciente-115 pasa a revisión en el padrón a las 1610.00.
# El Paciente-115 empieza la vacunación a las 1615.00.
# El Paciente-117 llega a las 1617.00.
# El Paciente-115 termina la vacunación a las 1621.00.
# El Paciente-115 es llevado a la salida a las 1621.00.
# El Paciente-116 entra a la fila a las 1623.00.
# El Paciente-115 se va a las 1623.00.
# El Paciente-116 pasa a revisión en el padrón a las 1623.00.
# El Paciente-116 empieza la vacunación a las 1628.00.
# El Paciente-118 llega a las 1633.00.
# El Paciente-116 termina la vacunación a las 1633.00.
# El Paciente-116 es llevado a la salida a las 1633.00.
# El Paciente-116 se va a las 1636.00.
# El Paciente-117 entra a la fila a las 1637.00.
# El Paciente-117 pasa a revisión en el padrón a las 1637.00.
# !X!X!X! El Paciente-117 no puede vacunarse y se retira a las 1639.00.
# El Paciente-117 se va a las 1639.00.
# El Paciente-119 llega a las 1646.00.
# El Paciente-118 entra a la fila a las 1653.00.
# El Paciente-118 pasa a revisión en el padrón a las 1653.00.
# El Paciente-118 empieza la vacunación a las 1655.00.
# El Paciente-120 llega a las 1658.00.
# El Paciente-118 termina la vacunación a las 1661.00.
# El Paciente-118 es llevado a la salida a las 1661.00.
# El Paciente-118 se va a las 1663.00.
# El Paciente-119 entra a la fila a las 1666.00.
# El Paciente-119 pasa a revisión en el padrón a las 1666.00.
# El Paciente-119 empieza la vacunación a las 1671.00.
# El Paciente-121 llega a las 1672.00.
# El Paciente-120 entra a la fila a las 1678.00.
# El Paciente-119 termina la vacunación a las 1678.00.
# El Paciente-119 es llevado a la salida a las 1678.00.
# El Paciente-120 pasa a revisión en el padrón a las 1678.00.
# El Paciente-119 se va a las 1679.00.
# El Paciente-120 empieza la vacunación a las 1681.00.
# El Paciente-122 llega a las 1688.00.
# El Paciente-120 termina la vacunación a las 1689.00.
# El Paciente-120 es llevado a la salida a las 1689.00.
# El Paciente-121 entra a la fila a las 1692.00.
# El Paciente-120 se va a las 1692.00.
# El Paciente-121 pasa a revisión en el padrón a las 1692.00.
# El Paciente-121 empieza la vacunación a las 1695.00.
# El Paciente-123 llega a las 1700.00.
# El Paciente-121 termina la vacunación a las 1705.00.
# El Paciente-121 es llevado a la salida a las 1705.00.
# El Paciente-121 se va a las 1707.00.
# El Paciente-122 entra a la fila a las 1708.00.
# El Paciente-122 pasa a revisión en el padrón a las 1708.00.
# El Paciente-122 empieza la vacunación a las 1713.00.
# El Paciente-124 llega a las 1715.00.
# El Paciente-122 termina la vacunación a las 1718.00.
# El Paciente-122 es llevado a la salida a las 1718.00.
# El Paciente-122 se va a las 1719.00.
# El Paciente-123 entra a la fila a las 1720.00.
# El Paciente-123 pasa a revisión en el padrón a las 1720.00.
# El Paciente-123 empieza la vacunación a las 1723.00.
# El Paciente-125 llega a las 1728.00.
# El Paciente-123 termina la vacunación a las 1731.00.
# El Paciente-123 es llevado a la salida a las 1731.00.
# El Paciente-123 se va a las 1732.00.
# El Paciente-124 entra a la fila a las 1735.00.
# El Paciente-124 pasa a revisión en el padrón a las 1735.00.
# El Paciente-124 empieza la vacunación a las 1738.00.
# El Paciente-126 llega a las 1743.00.
# El Paciente-124 termina la vacunación a las 1747.00.
# El Paciente-124 es llevado a la salida a las 1747.00.
# El Paciente-125 entra a la fila a las 1748.00.
# El Paciente-125 pasa a revisión en el padrón a las 1748.00.
# El Paciente-124 se va a las 1749.00.
# El Paciente-125 empieza la vacunación a las 1751.00.
# El Paciente-125 termina la vacunación a las 1757.00.
# El Paciente-125 es llevado a la salida a las 1757.00.
# El Paciente-127 llega a las 1759.00.
# El Paciente-125 se va a las 1759.00.
# El Paciente-126 entra a la fila a las 1763.00.
# El Paciente-126 pasa a revisión en el padrón a las 1763.00.
# El Paciente-126 empieza la vacunación a las 1766.00.
# El Paciente-126 termina la vacunación a las 1771.00.
# El Paciente-126 es llevado a la salida a las 1771.00.
# El Paciente-128 llega a las 1774.00.
# El Paciente-126 se va a las 1774.00.
# El Paciente-127 entra a la fila a las 1779.00.
# El Paciente-127 pasa a revisión en el padrón a las 1779.00.
# El Paciente-127 empieza la vacunación a las 1781.00.
# El Paciente-129 llega a las 1786.00.
# El Paciente-127 termina la vacunación a las 1789.00.
# El Paciente-127 es llevado a la salida a las 1789.00.
# El Paciente-127 se va a las 1791.00.
# El Paciente-128 entra a la fila a las 1794.00.
# El Paciente-128 pasa a revisión en el padrón a las 1794.00.
# El Paciente-128 empieza la vacunación a las 1797.00.
# El Paciente-130 llega a las 1800.00.
# El Paciente-129 entra a la fila a las 1806.00.
# El Paciente-128 termina la vacunación a las 1806.00.
# El Paciente-128 es llevado a la salida a las 1806.00.
# El Paciente-129 pasa a revisión en el padrón a las 1806.00.
# El Paciente-129 empieza la vacunación a las 1808.00.
# El Paciente-128 se va a las 1809.00.
# El Paciente-131 llega a las 1813.00.
# El Paciente-129 termina la vacunación a las 1816.00.
# El Paciente-129 es llevado a la salida a las 1816.00.
# El Paciente-129 se va a las 1818.00.
# El Paciente-130 entra a la fila a las 1820.00.
# El Paciente-130 pasa a revisión en el padrón a las 1820.00.
# El Paciente-130 empieza la vacunación a las 1824.00.
# El Paciente-132 llega a las 1828.00.
# El Paciente-130 termina la vacunación a las 1831.00.
# El Paciente-130 es llevado a la salida a las 1831.00.
# El Paciente-131 entra a la fila a las 1833.00.
# El Paciente-131 pasa a revisión en el padrón a las 1833.00.
# El Paciente-130 se va a las 1834.00.
# El Paciente-131 empieza la vacunación a las 1835.00.
# El Paciente-131 termina la vacunación a las 1841.00.
# El Paciente-131 es llevado a la salida a las 1841.00.
# El Paciente-131 se va a las 1843.00.
# El Paciente-133 llega a las 1845.00.
# El Paciente-132 entra a la fila a las 1848.00.
# El Paciente-132 pasa a revisión en el padrón a las 1848.00.
# El Paciente-132 empieza la vacunación a las 1850.00.
# El Paciente-134 llega a las 1857.00.
# El Paciente-132 termina la vacunación a las 1857.00.
# El Paciente-132 es llevado a la salida a las 1857.00.
# El Paciente-132 se va a las 1858.00.
# El Paciente-133 entra a la fila a las 1865.00.
# El Paciente-133 pasa a revisión en el padrón a las 1865.00.
# El Paciente-133 empieza la vacunación a las 1870.00.
# El Paciente-135 llega a las 1871.00.
# El Paciente-133 termina la vacunación a las 1876.00.
# El Paciente-133 es llevado a la salida a las 1876.00.
# El Paciente-134 entra a la fila a las 1877.00.
# El Paciente-134 pasa a revisión en el padrón a las 1877.00.
# El Paciente-133 se va a las 1878.00.
# El Paciente-134 empieza la vacunación a las 1879.00.
# El Paciente-136 llega a las 1886.00.
# El Paciente-134 termina la vacunación a las 1886.00.
# El Paciente-134 es llevado a la salida a las 1886.00.
# El Paciente-134 se va a las 1888.00.
# El Paciente-135 entra a la fila a las 1891.00.
# El Paciente-135 pasa a revisión en el padrón a las 1891.00.
# El Paciente-135 empieza la vacunación a las 1895.00.
# El Paciente-137 llega a las 1901.00.
# El Paciente-135 termina la vacunación a las 1902.00.
# El Paciente-135 es llevado a la salida a las 1902.00.
# El Paciente-135 se va a las 1904.00.
# El Paciente-136 entra a la fila a las 1906.00.
# El Paciente-136 pasa a revisión en el padrón a las 1906.00.
# El Paciente-136 empieza la vacunación a las 1910.00.
# El Paciente-138 llega a las 1913.00.
# El Paciente-136 termina la vacunación a las 1917.00.
# El Paciente-136 es llevado a la salida a las 1917.00.
# El Paciente-136 se va a las 1918.00.
# El Paciente-137 entra a la fila a las 1921.00.
# El Paciente-137 pasa a revisión en el padrón a las 1921.00.
# El Paciente-137 empieza la vacunación a las 1923.00.
# El Paciente-139 llega a las 1925.00.
# El Paciente-137 termina la vacunación a las 1931.00.
# El Paciente-137 es llevado a la salida a las 1931.00.
# El Paciente-138 entra a la fila a las 1933.00.
# El Paciente-137 se va a las 1933.00.
# El Paciente-138 pasa a revisión en el padrón a las 1933.00.
# El Paciente-138 empieza la vacunación a las 1937.00.
# El Paciente-140 llega a las 1941.00.
# El Paciente-139 entra a la fila a las 1945.00.
# El Paciente-138 termina la vacunación a las 1945.00.
# El Paciente-138 es llevado a la salida a las 1945.00.
# El Paciente-139 pasa a revisión en el padrón a las 1945.00.
# El Paciente-138 se va a las 1946.00.
# !X!X!X! El Paciente-139 no puede vacunarse y se retira a las 1950.00.
# El Paciente-139 se va a las 1950.00.
# El Paciente-141 llega a las 1958.00.
# El Paciente-140 entra a la fila a las 1961.00.
# El Paciente-140 pasa a revisión en el padrón a las 1961.00.
# El Paciente-140 empieza la vacunación a las 1964.00.
# El Paciente-142 llega a las 1972.00.
# El Paciente-140 termina la vacunación a las 1973.00.
# El Paciente-140 es llevado a la salida a las 1973.00.
# El Paciente-140 se va a las 1974.00.
# El Paciente-141 entra a la fila a las 1978.00.
# El Paciente-141 pasa a revisión en el padrón a las 1978.00.
# El Paciente-141 empieza la vacunación a las 1983.00.
# El Paciente-143 llega a las 1985.00.
# El Paciente-141 termina la vacunación a las 1988.00.
# El Paciente-141 es llevado a la salida a las 1988.00.
# El Paciente-141 se va a las 1991.00.
# El Paciente-142 entra a la fila a las 1992.00.
# El Paciente-142 pasa a revisión en el padrón a las 1992.00.
# El Paciente-142 empieza la vacunación a las 1996.00.
# El Paciente-144 llega a las 2000.00.
# El Paciente-143 entra a la fila a las 2005.00.
# El Paciente-142 termina la vacunación a las 2005.00.
# El Paciente-142 es llevado a la salida a las 2005.00.
# El Paciente-143 pasa a revisión en el padrón a las 2005.00.
# El Paciente-142 se va a las 2006.00.
# El Paciente-143 empieza la vacunación a las 2007.00.
# El Paciente-145 llega a las 2014.00.
# El Paciente-143 termina la vacunación a las 2016.00.
# El Paciente-143 es llevado a la salida a las 2016.00.
# El Paciente-143 se va a las 2017.00.
# El Paciente-144 entra a la fila a las 2020.00.
# El Paciente-144 pasa a revisión en el padrón a las 2020.00.
# El Paciente-144 empieza la vacunación a las 2024.00.
# El Paciente-144 termina la vacunación a las 2029.00.
# El Paciente-144 es llevado a la salida a las 2029.00.
# El Paciente-144 se va a las 2030.00.
# El Paciente-146 llega a las 2031.00.
# El Paciente-145 entra a la fila a las 2034.00.
# El Paciente-145 pasa a revisión en el padrón a las 2034.00.
# El Paciente-145 empieza la vacunación a las 2039.00.
# El Paciente-147 llega a las 2046.00.
# El Paciente-145 termina la vacunación a las 2049.00.
# El Paciente-145 es llevado a la salida a las 2049.00.
# El Paciente-146 entra a la fila a las 2051.00.
# El Paciente-145 se va a las 2051.00.
# El Paciente-146 pasa a revisión en el padrón a las 2051.00.
# !X!X!X! El Paciente-146 no puede vacunarse y se retira a las 2056.00.
# El Paciente-146 se va a las 2056.00.
# El Paciente-148 llega a las 2062.00.
# El Paciente-147 entra a la fila a las 2066.00.
# El Paciente-147 pasa a revisión en el padrón a las 2066.00.
# El Paciente-147 empieza la vacunación a las 2068.00.
# El Paciente-147 termina la vacunación a las 2076.00.
# El Paciente-147 es llevado a la salida a las 2076.00.
# El Paciente-149 llega a las 2078.00.
# El Paciente-147 se va a las 2079.00.
# El Paciente-148 entra a la fila a las 2082.00.
# El Paciente-148 pasa a revisión en el padrón a las 2082.00.
# El Paciente-148 empieza la vacunación a las 2087.00.
# El Paciente-150 llega a las 2095.00.
# El Paciente-148 termina la vacunación a las 2095.00.
# El Paciente-148 es llevado a la salida a las 2095.00.
# El Paciente-148 se va a las 2096.00.
# El Paciente-149 entra a la fila a las 2098.00.
# El Paciente-149 pasa a revisión en el padrón a las 2098.00.

# %%
# Resultados y Gráficas

print("Pacientes en el día: ", pacientes)
print("Pacientes Vacunados Totalmente: ", pacientes_atendidos)
print("Pacientes No Vacunados: ", no_vacunados)
# Out:
# Pacientes en el día:  150
# Pacientes Vacunados Totalmente:  139
# Pacientes No Vacunados:  9
