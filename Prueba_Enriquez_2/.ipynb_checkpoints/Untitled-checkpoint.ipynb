# %% [markdown]
# # PRUEBA DE SIMULACIÓN - RETORNO A CLASES
# ### Alejandro Enríquez
# ### Ingeniería en Ciencias de la Computación
# ### 10mo Ciclo
#
# Objetivo: considerando los datos oficiales del ministerio de educación, obtener de una institución educativa la cantidad de estudiantes y docentes que existen, para obtener una simulación que mantenga las siguientes consideraciones.
#
# - Considerar solo una institución
# - El 90% de los docentes podrán volver, ya que están vacunados.
# - El 5% al 10% de los estudiantes no podrán volver
# - Despues de 30 días se realiza una prueba covid al 10% de los estudiantes. 2% son positivos. Si es positivo se cierra todo el curso
# - La jornada estudiantil es de 6 horas
# - Tienen un receso de 30 minutos, donde el foco de contagio es del 2%
#
# Se debe obtener como resultados:
#
# - Animación 2D/3D
# - Cuantos contagios a fin de mes
# - Cursos cerrados
# - Entrada y salida de docentes a fin de mes
#
# Generar gráficas que indiquen las personas que presentaron complicaciones en base a los tiempos, estado de las personas y respuesta

# %%
# Imports
import simpy
import random
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
random.seed(76)

# %%
# Cargar los datos
data = pd.read_excel('data.xlsx')
institucion = data[245:246]
institucion
# Out:
#          PARROQUIA  CODIGO_PARROQUIA  NOMBRE CODIGO_INSTITUCION  \
# 245  SAN SEBASTIAN             10111  MADRID           01H00338
#
#         TIPO_EDUCACION SOSTENIMIENTO        ZONA   MODALIDAD  DOCENTES  \
# 245  Educación Regular    Particular  UrbanaINEC  Presencial        13
#
#      TOTAL_ESTUDIANTES
# 245                172

# %%
# Procesamiento de los datos
DOCENTES = round((int(institucion['DOCENTES']*90)/100))
DOCENTES_INICIO = DOCENTES
ESTUDIANTES = round((int(institucion['TOTAL_ESTUDIANTES'])*random.randint(90,100))/100)
JORNADA = 360
TIEMPO = 60
RECESO = 30
EST_AULA = round(ESTUDIANTES/DOCENTES)
FOCO_CONTAGIO = 2

contagios = 0
cursos_cerrados = 0
es_docentes = 0
periodo = 0

proceso = pd.DataFrame(columns=['dia','total_cursos','cursos_cerrados','retorno_docente'])

# %%
# Clase
class Retorno(object):
    def __init__(self, environment, num_docentes, num_estudiantes):
        self.env = environment
        self.docentes = simpy.Resource(environment, num_docentes)
        self.estudiantes = num_estudiantes
        #self.accion = env.process(self.clases())
        
    def clases(self):
        global periodo
        global contagios
        print(periodo)
        try:
            if periodo == 1:
                print('Inicia el día a las: %.2f.' % env.now)
                yield self.env.timeout(JORNADA/2)
                print('Inicia el recreo a las: %.2f.' % env.now)
                print('Se realizan las pruebas PCR')
                contagio = FOCO_CONTAGIO + random.randint(0,2)
                if(contagio < random.randint(1,100)):
                    pr = round((EST_AULA*contagio)/100)
                    print("Se hace la prueba a",EST_AULA," estudiantes y salen",pr ,"contagiados ")
                    if pr == 1:
                        self.interrumpir()
                        contagios += 1
                else:
                    yield self.env.timeout(JORNADA/2)
            else:
                print('Inicia el día a las: %.2f.' % env.now)
                yield self.env.timeout(JORNADA/2)
                print('Inicia el recreo a las: %.2f.' % env.now)
                yield self.env.timeout(RECESO)
                print('Termina el recreo y se reinician las clases a las %.2f.' % env.now)
                yield self.env.timeout(JORNADA/2)
                print('Finaliza el día a las: %.2f.' % env.now)
        except simpy.Interrupt:
            DOCENTES = DOCENTES-1
            
    def interrumpir(self):
        global DOCENTES
        global cursos_cerrados
        print('¡Se cierra la clase por contagio!')
        #self.accion.interrupt()
        DOCENTES = DOCENTES-1
        cursos_cerrados += 1

# %%
# Procesos
def llegada_estudiantes(env, retorno):
    with retorno.docentes.request() as docente:
        yield docente
        yield env.process(retorno.clases())
        
def ejecutar_simulacion(env, num_docentes, num_estudiantes):
    retorno = Retorno(env, num_docentes, num_estudiantes)
    yield env.process(llegada_estudiantes(env, retorno))

# %%
# Simulación 
print("Iniciando retorno a clases")

for i in range(TIEMPO):
    env = simpy.Environment()
    print("Las aulas disponibles del día ", i+1, " son: ", DOCENTES)
    #print("Las aulas disponibles son: ", DOCENTES)
    env.process(ejecutar_simulacion(env, DOCENTES, ESTUDIANTES))
    env.run(until=JORNADA)
    if i > 28:
        print("################### EMPIEZAN LAS PRUEBAS PCR ####################")
        periodo = 1
        
    con = 0
    if i % 18 == 0 and i>18:
        es_docentes += 1
        print("Pasaron 20 días")
        DOCENTES = DOCENTES + 1
    
    dia = [i+1, DOCENTES, cursos_cerrados, es_docentes]
    proceso.loc[len(proceso)] = dia
        
print("Contagios", contagios)
print("Cursos cerrados", cursos_cerrados)
print("Retorno de los Docentes", es_docentes)

proceso
# Out:
# Iniciando retorno a clases
# Las aulas disponibles del día  1  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  2  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  3  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  4  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  5  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  6  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  7  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  8  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  9  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  10  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  11  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  12  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  13  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  14  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  15  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  16  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  17  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  18  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  19  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  20  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  21  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  22  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  23  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  24  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  25  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  26  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  27  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  28  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  29  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# Las aulas disponibles del día  30  son:  12
# 0
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Termina el recreo y se reinician las clases a las 210.00.
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  31  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  32  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  33  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  34  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  35  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  36  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  37  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Pasaron 20 días
# Las aulas disponibles del día  38  son:  13
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  39  son:  13
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  40  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  41  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  42  son:  12
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  43  son:  11
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  44  son:  10
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  45  son:  10
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  46  son:  10
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  47  son:  10
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  48  son:  9
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  49  son:  9
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  50  son:  9
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  51  son:  8
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  52  son:  7
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  53  son:  7
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  54  son:  6
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  55  son:  5
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Pasaron 20 días
# Las aulas disponibles del día  56  son:  6
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  57  son:  6
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  58  son:  6
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  59  son:  6
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 1 contagiados
# ¡Se cierra la clase por contagio!
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Las aulas disponibles del día  60  son:  5
# 1
# Inicia el día a las: 0.00.
# Inicia el recreo a las: 180.00.
# Se realizan las pruebas PCR
# Se hace la prueba a 14  estudiantes y salen 0 contagiados
# ################### EMPIEZAN LAS PRUEBAS PCR ####################
# Contagios 9
# Cursos cerrados 9
# Retorno de los Docentes 2
#    dia total_cursos cursos_cerrados retorno_docente
# 0    1           12               0               0
# 1    2           12               0               0
# 2    3           12               0               0
# 3    4           12               0               0
# 4    5           12               0               0
# 5    6           12               0               0
# 6    7           12               0               0
# 7    8           12               0               0
# 8    9           12               0               0
# 9   10           12               0               0
# 10  11           12               0               0
# 11  12           12               0               0
# 12  13           12               0               0
# 13  14           12               0               0
# 14  15           12               0               0
# 15  16           12               0               0
# 16  17           12               0               0
# 17  18           12               0               0
# 18  19           12               0               0
# 19  20           12               0               0
# 20  21           12               0               0
# 21  22           12               0               0
# 22  23           12               0               0
# 23  24           12               0               0
# 24  25           12               0               0
# 25  26           12               0               0
# 26  27           12               0               0
# 27  28           12               0               0
# 28  29           12               0               0
# 29  30           12               0               0
# 30  31           12               0               0
# 31  32           12               0               0
# 32  33           12               0               0
# 33  34           12               0               0
# 34  35           12               0               0
# 35  36           12               0               0
# 36  37           13               0               1
# 37  38           13               0               1
# 38  39           12               1               1
# 39  40           12               1               1
# 40  41           12               1               1
# 41  42           11               2               1
# 42  43           10               3               1
# 43  44           10               3               1
# 44  45           10               3               1
# 45  46           10               3               1
# 46  47            9               4               1
# 47  48            9               4               1
# 48  49            9               4               1
# 49  50            8               5               1
# 50  51            7               6               1
# 51  52            7               6               1
# 52  53            6               7               1
# 53  54            5               8               1
# 54  55            6               8               2
# 55  56            6               8               2
# 56  57            6               8               2
# 57  58            6               8               2
# 58  59            5               9               2
# 59  60            5               9               2

# %%
# Gráfica y resultados
fig = plt.figure(figsize=(20,10))

labels = ['Total de Cursos', 'Cursos Cerrados', 'Estudiantes positivos PCR', 'Docentes que retornaron']
datos = [DOCENTES_INICIO, cursos_cerrados, contagios, es_docentes]
plt.grid()
plt.title('Simulación Retorno a Clases')
plt.bar(labels, datos)
plt.show()

# %%
dias = proceso['dia'].unique()
def animacion(i):
    day = dias[i]
    data_temp = proceso.loc[proceso['dia'] == day, :]
    plt.clear()
    plt.barh(data_temp.total_cursos, data_temp.total_cursos)
    label.set_text(day)

anim = animation.FuncAnimation(fig, animacion, frames = len(dias))
anim.save('Prueba.gif')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1127             for anim in all_anim:
# -> 1128                 anim._init_draw()  # Clear the initial frame
#    1129             frame_number = 0
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1702         if self._init_func is None:
# -> 1703             self._draw_frame(next(self.new_frame_seq()))
#    1704
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in _draw_frame(self, framedata)
#    1725         # func needs to return a sequence of any artists that were modified.
# -> 1726         self._drawn_artists = self._func(framedata, *self._args)
#    1727         if self._blit:
#
# <ipython-input-23-b507dda10906> in animacion(i)
#       4     data_temp = proceso.loc[proceso['dia'] == day, :]
# ----> 5     plt.clear()
#       6     plt.barh(data_temp.total_cursos, data_temp.total_cursos)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'clear'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b507dda10906> in <module>
#       8
#       9 anim = animation.FuncAnimation(fig, animacion, frames = len(dias))
# ---> 10 anim.save('Prueba.gif')
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     552
#     553     def finish(self):
# --> 554         self._frames[0].save(
#     555             self.outfile, save_all=True, append_images=self._frames[1:],
#     556             duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range
